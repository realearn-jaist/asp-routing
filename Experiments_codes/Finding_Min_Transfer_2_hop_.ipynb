# %%
# !sudo add-apt-repository -y ppa:potassco/stable
# !sudo apt-get update
# !apt install clingo
# !pip install potassco
# Out:
# Repository: 'deb https://ppa.launchpadcontent.net/potassco/stable/ubuntu/ jammy main'
# Description:
# Contains the stable releases of systems from the https://potassco.org project.
# More info: https://launchpad.net/~potassco/+archive/ubuntu/stable
# Adding repository.
# Adding deb entry to /etc/apt/sources.list.d/potassco-ubuntu-stable-jammy.list
# Adding disabled deb-src entry to /etc/apt/sources.list.d/potassco-ubuntu-stable-jammy.list
# Adding key to /etc/apt/trusted.gpg.d/potassco-ubuntu-stable.gpg with fingerprint 7AA3F20F5BDCBF2F78090C08DE1AB6C94EFE9A64
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [830 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Hit:8 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,798 kB]
# Hit:11 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,374 kB]
# Get:13 https://ppa.launchpadcontent.net/potassco/stable/ubuntu jammy InRelease [18.0 kB]
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,082 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [2,445 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [2,110 kB]
# Get:18 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 Packages [27.8 kB]
# Get:19 https://ppa.launchpadcontent.net/potassco/stable/ubuntu jammy/main amd64 Packages [3,084 B]
# Fetched 10.0 MB in 5s (2,068 kB/s)
# Reading package lists... Done
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:7 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/potassco/stable/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libclingo liblua5.3-0 python3-clingo
# The following NEW packages will be installed:
#   clingo libclingo liblua5.3-0 python3-clingo
# 0 upgraded, 4 newly installed, 0 to remove and 52 not upgraded.
# Need to get 2,146 kB of archives.
# After this operation, 7,504 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblua5.3-0 amd64 5.3.6-1build1 [140 kB]
# Get:2 https://ppa.launchpadcontent.net/potassco/stable/ubuntu jammy/main amd64 libclingo amd64 5.7.1-jammy1 [1,219 kB]
# Get:3 https://ppa.launchpadcontent.net/potassco/stable/ubuntu jammy/main amd64 python3-clingo amd64 5.7.1-jammy1 [110 kB]
# Get:4 https://ppa.launchpadcontent.net/potassco/stable/ubuntu jammy/main amd64 clingo amd64 5.7.1-jammy1 [676 kB]
# Fetched 2,146 kB in 4s (498 kB/s)
# Selecting previously unselected package libclingo.
# (Reading database ... 121918 files and directories currently installed.)
# Preparing to unpack .../libclingo_5.7.1-jammy1_amd64.deb ...
# Unpacking libclingo (5.7.1-jammy1) ...
# Selecting previously unselected package liblua5.3-0:amd64.
# Preparing to unpack .../liblua5.3-0_5.3.6-1build1_amd64.deb ...
# Unpacking liblua5.3-0:amd64 (5.3.6-1build1) ...
# Selecting previously unselected package python3-clingo.
# Preparing to unpack .../python3-clingo_5.7.1-jammy1_amd64.deb ...
# Unpacking python3-clingo (5.7.1-jammy1) ...
# Selecting previously unselected package clingo.
# Preparing to unpack .../clingo_5.7.1-jammy1_amd64.deb ...
# Unpacking clingo (5.7.1-jammy1) ...
# Setting up libclingo (5.7.1-jammy1) ...
# Setting up python3-clingo (5.7.1-jammy1) ...
# Setting up liblua5.3-0:amd64 (5.3.6-1build1) ...
# Setting up clingo (5.7.1-jammy1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# ERROR: Could not find a version that satisfies the requirement potassco (from versions: none)
# ERROR: No matching distribution found for potassco

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import math
import ast
import heapq
import networkx as nx
import time
import subprocess

# %%
csv_path = "https://raw.githubusercontent.com/DigitalSuYee/GPS-Data/main/bus_plan%20(1).csv"
bus_plan = pd.read_csv(csv_path)

bus_plan
# Out:
#      sid1  sid2 route      mins
# 0    5188  3818     a  2.000000
# 1    3818  3820     a  5.000000
# 2    3820  3821     a  8.000000
# 3    3821  3528     a  5.000000
# 4    3528  3529     a  2.000000
# ..    ...   ...   ...       ...
# 415  4099  4006     w  5.537429
# 416  4216  4291     w  4.408196
# 417  4291  4216     w  4.408196
# 418  4218  4222     w  9.236181
# 419  4222  4218     w  9.236181
#
# [420 rows x 4 columns]

# %%
bus_plan['route'].unique()
# Out:
# array(['a', 'd', 'c', 'b', 'e', 'w'], dtype=object)

# %%
stops_list = sorted(set(bus_plan['sid1']).union(set(bus_plan['sid2'])))
stops_code = " ".join([f"stop(s{i})." for i in stops_list])

# %%
stops_code
# Out:
# 'stop(s367). stop(s369). stop(s373). stop(s381). stop(s836). stop(s839). stop(s843). stop(s846). stop(s847). stop(s878). stop(s882). stop(s887). stop(s890). stop(s904). stop(s906). stop(s910). stop(s965). stop(s966). stop(s968). stop(s970). stop(s974). stop(s975). stop(s978). stop(s979). stop(s980). stop(s981). stop(s982). stop(s983). stop(s985). stop(s987). stop(s1049). stop(s1050). stop(s1051). stop(s1052). stop(s1054). stop(s1055). stop(s1335). stop(s1339). stop(s1341). stop(s1343). stop(s1346). stop(s1349). stop(s1353). stop(s1355). stop(s1424). stop(s1595). stop(s1598). stop(s1600). stop(s1602). stop(s1606). stop(s1608). stop(s1610). stop(s1612). stop(s1613). stop(s1615). stop(s1619). stop(s1622). stop(s1624). stop(s1629). stop(s1631). stop(s1634). stop(s1642). stop(s1646). stop(s1671). stop(s1676). stop(s1783). stop(s1785). stop(s1786). stop(s1788). stop(s1789). stop(s1791). stop(s1792). stop(s1795). stop(s1820). stop(s1823). stop(s1838). stop(s1887). stop(s1906). stop(s2022). stop(s2024). stop(s2031). stop(s2038). stop(s2039). stop(s2040). stop(s2044). stop(s2133). stop(s2135). stop(s2138). stop(s2140). stop(s2223). stop(s2228). stop(s2231). stop(s2232). stop(s2237). stop(s2240). stop(s2381). stop(s2382). stop(s2384). stop(s2386). stop(s2387). stop(s2476). stop(s2477). stop(s2612). stop(s2614). stop(s2618). stop(s2622). stop(s2663). stop(s2712). stop(s2713). stop(s2717). stop(s2763). stop(s2843). stop(s2845). stop(s2847). stop(s2848). stop(s2850). stop(s2851). stop(s2854). stop(s2855). stop(s2859). stop(s2862). stop(s2898). stop(s2899). stop(s2900). stop(s2905). stop(s2906). stop(s2909). stop(s2932). stop(s3032). stop(s3033). stop(s3036). stop(s3037). stop(s3044). stop(s3047). stop(s3050). stop(s3053). stop(s3056). stop(s3061). stop(s3066). stop(s3069). stop(s3070). stop(s3071). stop(s3072). stop(s3076). stop(s3083). stop(s3084). stop(s3091). stop(s3095). stop(s3097). stop(s3184). stop(s3185). stop(s3189). stop(s3190). stop(s3191). stop(s3192). stop(s3194). stop(s3195). stop(s3197). stop(s3199). stop(s3200). stop(s3201). stop(s3205). stop(s3209). stop(s3210). stop(s3230). stop(s3232). stop(s3234). stop(s3235). stop(s3238). stop(s3240). stop(s3241). stop(s3242). stop(s3243). stop(s3244). stop(s3246). stop(s3247). stop(s3250). stop(s3251). stop(s3253). stop(s3255). stop(s3256). stop(s3360). stop(s3362). stop(s3364). stop(s3368). stop(s3370). stop(s3413). stop(s3416). stop(s3417). stop(s3419). stop(s3420). stop(s3431). stop(s3442). stop(s3444). stop(s3447). stop(s3450). stop(s3528). stop(s3529). stop(s3530). stop(s3531). stop(s3533). stop(s3535). stop(s3536). stop(s3537). stop(s3539). stop(s3540). stop(s3541). stop(s3543). stop(s3545). stop(s3546). stop(s3549). stop(s3550). stop(s3551). stop(s3553). stop(s3555). stop(s3556). stop(s3558). stop(s3559). stop(s3560). stop(s3562). stop(s3566). stop(s3568). stop(s3571). stop(s3573). stop(s3579). stop(s3583). stop(s3585). stop(s3586). stop(s3722). stop(s3723). stop(s3726). stop(s3728). stop(s3729). stop(s3746). stop(s3750). stop(s3753). stop(s3757). stop(s3767). stop(s3768). stop(s3812). stop(s3814). stop(s3818). stop(s3820). stop(s3821). stop(s3917). stop(s3920). stop(s3925). stop(s3926). stop(s3927). stop(s3983). stop(s3984). stop(s3989). stop(s3992). stop(s4004). stop(s4006). stop(s4008). stop(s4010). stop(s4012). stop(s4014). stop(s4016). stop(s4017). stop(s4086). stop(s4088). stop(s4090). stop(s4091). stop(s4092). stop(s4094). stop(s4097). stop(s4098). stop(s4099). stop(s4101). stop(s4155). stop(s4157). stop(s4216). stop(s4218). stop(s4219). stop(s4220). stop(s4222). stop(s4232). stop(s4246). stop(s4253). stop(s4257). stop(s4291). stop(s4360). stop(s4488). stop(s4567). stop(s4768). stop(s4774). stop(s4776). stop(s4822). stop(s4827). stop(s4963). stop(s5188). stop(s5212). stop(s5213). stop(s5214). stop(s5215). stop(s5307). stop(s5308). stop(s5309). stop(s5310). stop(s5325). stop(s5348). stop(s5401). stop(s5426). stop(s5477).'

# %%
lines_code = ""
for index, row in bus_plan.iterrows():
    sid1 = int(row['sid1'])
    sid2 = int(row['sid2'])
    route = str(row['route'])
    mins = int(row['mins'])
    lines_code += f"line(s{sid1}, s{sid2}, {route}, {mins}). "

# %%
lines_code
# Out:
# 'line(s5188, s3818, a, 2). line(s3818, s3820, a, 5). line(s3820, s3821, a, 8). line(s3821, s3528, a, 5). line(s3528, s3529, a, 2). line(s3529, s381, a, 9). line(s381, s3530, a, 6). line(s3530, s3531, a, 3). line(s3531, s2387, a, 3). line(s2387, s2663, a, 5). line(s2663, s3533, a, 9). line(s3533, s3535, a, 6). line(s3535, s3536, a, 9). line(s3536, s3537, a, 7). line(s3537, s3539, a, 10). line(s3539, s3540, a, 10). line(s3540, s3541, a, 2). line(s3541, s3543, a, 9). line(s3543, s3545, a, 2). line(s3545, s3546, a, 3). line(s3546, s3549, a, 2). line(s3549, s3550, a, 9). line(s3550, s3551, a, 8). line(s3551, s3553, a, 10). line(s3553, s3555, a, 7). line(s3555, s4246, a, 6). line(s4246, s3556, a, 10). line(s3556, s3558, a, 5). line(s3558, s3559, a, 2). line(s3559, s3562, a, 3). line(s3562, s2763, a, 6). line(s2763, s2843, a, 5). line(s2843, s2845, a, 6). line(s2845, s2847, a, 16). line(s2847, s2848, a, 7). line(s2848, s2932, a, 19). line(s2932, s5307, a, 4). line(s5307, s2612, a, 9). line(s2612, s2614, a, 10). line(s2614, s2618, a, 7). line(s2618, s2622, a, 17). line(s2622, s2850, a, 12). line(s2850, s2851, a, 3). line(s2851, s2854, a, 12). line(s2854, s5308, a, 6). line(s5308, s2855, a, 9). line(s2855, s2859, a, 16). line(s2859, s5309, a, 10). line(s5309, s4774, a, 5). line(s4774, s5310, a, 16). line(s5310, s2862, a, 8). line(s2862, s4776, a, 10). line(s4776, s3767, a, 3). line(s3767, s3768, a, 8). line(s3722, s3723, d, 3). line(s3723, s3726, d, 8). line(s3726, s3728, d, 10). line(s3728, s3729, d, 7). line(s3729, s2898, d, 8). line(s2898, s2899, d, 5). line(s2899, s2900, d, 6). line(s2900, s1791, d, 16). line(s1791, s1792, d, 6). line(s1792, s1795, d, 6). line(s1795, s1823, d, 8). line(s1823, s1820, d, 10). line(s1820, s1823, d, 4). line(s1823, s1783, d, 5). line(s1783, s1785, d, 4). line(s1785, s1786, d, 9). line(s1786, s4827, d, 3). line(s4827, s2905, d, 2). line(s2905, s2906, d, 8). line(s2906, s2909, d, 7). line(s2909, s1838, d, 5). line(s1838, s3750, d, 4). line(s3750, s3746, d, 9). line(s3746, s3750, d, 3). line(s3750, s3753, d, 4). line(s3753, s3757, d, 8). line(s978, s980, c, 8). line(s980, s981, c, 9). line(s981, s3200, c, 7). line(s3200, s3241, c, 3). line(s3241, s3243, c, 6). line(s3243, s4232, c, 4). line(s4232, s3244, c, 10). line(s3244, s3246, c, 4). line(s3246, s982, c, 10). line(s982, s983, c, 6). line(s983, s985, c, 7). line(s985, s987, c, 5). line(s987, s1676, c, 5). line(s1676, s3256, c, 6). line(s4008, s4012, c, 6). line(s4012, s5426, c, 10). line(s5426, s1335, c, 10). line(s1335, s1339, c, 8). line(s1339, s1341, c, 2). line(s1341, s1343, c, 5). line(s1343, s3360, c, 3). line(s3360, s3362, c, 4). line(s3362, s3364, c, 7). line(s3364, s4222, c, 5). line(s4222, s3413, c, 2). line(s3413, s3416, c, 5). line(s3416, s3417, c, 7). line(s3417, s3419, c, 8). line(s3419, s3420, c, 10). line(s3420, s3032, c, 5). line(s3032, s3033, c, 9). line(s3033, s2717, c, 6). line(s2717, s3069, c, 2). line(s3069, s3070, c, 10). line(s3070, s4291, c, 3). line(s4291, s4567, c, 4). line(s4567, s3586, c, 5). line(s3586, s1906, c, 2). line(s1906, s4963, c, 6). line(s3583, s3585, c, 7). line(s3585, s4567, c, 9). line(s4567, s4216, c, 4). line(s4216, s3071, c, 7). line(s3071, s3072, c, 8). line(s3072, s2712, c, 4). line(s2712, s2713, c, 3). line(s2713, s4155, c, 5). line(s4155, s3442, c, 6). line(s3442, s3444, c, 3). line(s3444, s3447, c, 6). line(s3447, s3450, c, 7). line(s3450, s4218, c, 9). line(s4218, s3368, c, 6). line(s3368, s3370, c, 6). line(s3370, s4219, c, 7). line(s4219, s4220, c, 8). line(s4220, s1346, c, 8). line(s1346, s1349, c, 8). line(s1349, s1353, c, 9). line(s1353, s1355, c, 9). line(s1355, s4090, c, 2). line(s4090, s4091, c, 4). line(s4091, s4098, c, 10). line(s4098, s4253, c, 10). line(s4253, s3184, c, 3). line(s3184, s1642, c, 9). line(s1642, s1646, c, 10). line(s1646, s965, c, 8). line(s965, s966, c, 10). line(s966, s968, c, 10). line(s968, s970, c, 4). line(s970, s3192, c, 6). line(s3192, s3195, c, 6). line(s3195, s319 ...

# %%
code = """
line(s5188, s3818, a, 2). line(s3818, s3820, a, 5). line(s3820, s3821, a, 8). line(s3821, s3528, a, 5). line(s3528, s3529, a, 2). line(s3529, s381, a, 9). line(s381, s3530, a, 6). line(s3530, s3531, a, 3). line(s3531, s2387, a, 3). line(s2387, s2663, a, 5). line(s2663, s3533, a, 9). line(s3533, s3535, a, 6). line(s3535, s3536, a, 9). line(s3536, s3537, a, 7). line(s3537, s3539, a, 10). line(s3539, s3540, a, 10). line(s3540, s3541, a, 2). line(s3541, s3543, a, 9). line(s3543, s3545, a, 2). line(s3545, s3546, a, 3). line(s3546, s3549, a, 2). line(s3549, s3550, a, 9). line(s3550, s3551, a, 8). line(s3551, s3553, a, 10). line(s3553, s3555, a, 7). line(s3555, s4246, a, 6). line(s4246, s3556, a, 10). line(s3556, s3558, a, 5). line(s3558, s3559, a, 2). line(s3559, s3562, a, 3). line(s3562, s2763, a, 6). line(s2763, s2843, a, 5). line(s2843, s2845, a, 6). line(s2845, s2847, a, 16). line(s2847, s2848, a, 7). line(s2848, s2932, a, 19). line(s2932, s5307, a, 4). line(s5307, s2612, a, 9). line(s2612, s2614, a, 10). line(s2614, s2618, a, 7). line(s2618, s2622, a, 17). line(s2622, s2850, a, 12). line(s2850, s2851, a, 3). line(s2851, s2854, a, 12). line(s2854, s5308, a, 6). line(s5308, s2855, a, 9). line(s2855, s2859, a, 16). line(s2859, s5309, a, 10). line(s5309, s4774, a, 5). line(s4774, s5310, a, 16). line(s5310, s2862, a, 8). line(s2862, s4776, a, 10). line(s4776, s3767, a, 3). line(s3767, s3768, a, 8). line(s3722, s3723, d, 3). line(s3723, s3726, d, 8). line(s3726, s3728, d, 10). line(s3728, s3729, d, 7). line(s3729, s2898, d, 8). line(s2898, s2899, d, 5). line(s2899, s2900, d, 6). line(s2900, s1791, d, 16). line(s1791, s1792, d, 6). line(s1792, s1795, d, 6). line(s1795, s1823, d, 8). line(s1823, s1820, d, 10). line(s1820, s1823, d, 4). line(s1823, s1783, d, 5). line(s1783, s1785, d, 4). line(s1785, s1786, d, 9). line(s1786, s4827, d, 3). line(s4827, s2905, d, 2). line(s2905, s2906, d, 8). line(s2906, s2909, d, 7). line(s2909, s1838, d, 5). line(s1838, s3750, d, 4). line(s3750, s3746, d, 9). line(s3746, s3750, d, 3). line(s3750, s3753, d, 4). line(s3753, s3757, d, 8). line(s978, s980, c, 8). line(s980, s981, c, 9). line(s981, s3200, c, 7). line(s3200, s3241, c, 3). line(s3241, s3243, c, 6). line(s3243, s4232, c, 4). line(s4232, s3244, c, 10). line(s3244, s3246, c, 4). line(s3246, s982, c, 10). line(s982, s983, c, 6). line(s983, s985, c, 7). line(s985, s987, c, 5). line(s987, s1676, c, 5). line(s1676, s3256, c, 6). line(s4008, s4012, c, 6). line(s4012, s5426, c, 10). line(s5426, s1335, c, 10). line(s1335, s1339, c, 8). line(s1339, s1341, c, 2). line(s1341, s1343, c, 5). line(s1343, s3360, c, 3). line(s3360, s3362, c, 4). line(s3362, s3364, c, 7). line(s3364, s4222, c, 5). line(s4222, s3413, c, 2). line(s3413, s3416, c, 5). line(s3416, s3417, c, 7). line(s3417, s3419, c, 8). line(s3419, s3420, c, 10). line(s3420, s3032, c, 5). line(s3032, s3033, c, 9). line(s3033, s2717, c, 6). line(s2717, s3069, c, 2). line(s3069, s3070, c, 10). line(s3070, s4291, c, 3). line(s4291, s4567, c, 4). line(s4567, s3586, c, 5). line(s3586, s1906, c, 2). line(s1906, s4963, c, 6). line(s3583, s3585, c, 7). line(s3585, s4567, c, 9). line(s4567, s4216, c, 4). line(s4216, s3071, c, 7). line(s3071, s3072, c, 8). line(s3072, s2712, c, 4). line(s2712, s2713, c, 3). line(s2713, s4155, c, 5). line(s4155, s3442, c, 6). line(s3442, s3444, c, 3). line(s3444, s3447, c, 6). line(s3447, s3450, c, 7). line(s3450, s4218, c, 9). line(s4218, s3368, c, 6). line(s3368, s3370, c, 6). line(s3370, s4219, c, 7). line(s4219, s4220, c, 8). line(s4220, s1346, c, 8). line(s1346, s1349, c, 8). line(s1349, s1353, c, 9). line(s1353, s1355, c, 9). line(s1355, s4090, c, 2). line(s4090, s4091, c, 4). line(s4091, s4098, c, 10). line(s4098, s4253, c, 10). line(s4253, s3184, c, 3). line(s3184, s1642, c, 9). line(s1642, s1646, c, 10). line(s1646, s965, c, 8). line(s965, s966, c, 10). line(s966, s968, c, 10). line(s968, s970, c, 4). line(s970, s3192, c, 6). line(s3192, s3195, c, 6). line(s3195, s3199, c, 10). line(s3199, s974, c, 10). line(s974, s979, c, 9). line(s979, s975, c, 2). line(s4768, s3431, b, 10). line(s3431, s1424, b, 2). line(s1424, s3579, b, 4). line(s3579, s4360, b, 15). line(s4360, s2039, b, 9). line(s2039, s2044, b, 2). line(s2044, s2138, b, 12). line(s2138, s2140, b, 10). line(s2140, s1051, b, 6). line(s1051, s1054, b, 2). line(s1054, s1055, b, 16). line(s1055, s3036, b, 5). line(s3036, s3037, b, 5). line(s3037, s4822, b, 6). line(s4822, s3983, b, 12). line(s3983, s3984, b, 11). line(s3984, s5348, b, 3). line(s5348, s3989, b, 14). line(s3989, s3992, b, 11). line(s3992, s3821, b, 9). line(s3821, s381, b, 19). line(s381, s4099, b, 12). line(s4099, s4101, b, 10). line(s4101, s4004, b, 5). line(s4004, s3076, b, 8). line(s3076, s373, b, 7). line(s373, s3083, b, 9). line(s3083, s3084, b, 7). line(s3084, s3091, b, 6). line(s3091, s3095, b, 10). line(s3095, s3097, b, 6). line(s3097, s1671, b, 7). line(s1671, s2031, b, 5). line(s2031, s4488, b, 3). line(s4488, s2476, b, 8). line(s2476, s2477, b, 6). line(s2477, s2022, b, 9). line(s2022, s2024, b, 8). line(s2024, s1887, b, 8). line(s1887, s3044, b, 5). line(s3044, s3047, b, 4). line(s3047, s3050, b, 6). line(s3050, s3053, b, 4). line(s3053, s3056, b, 6). line(s3056, s3061, b, 8). line(s3061, s3066, b, 4). line(s3066, s4006, b, 4). line(s4006, s3560, b, 2). line(s3560, s3566, b, 6). line(s3566, s3568, b, 7). line(s3568, s3571, b, 5). line(s3571, s3573, b, 5). line(s3573, s5401, b, 3). line(s5401, s2223, b, 4). line(s2223, s2228, b, 3). line(s2228, s2231, b, 4). line(s2231, s2232, b, 5). line(s2232, s4257, b, 9). line(s4257, s2237, b, 4). line(s2237, s2240, b, 5). line(s2240, s3812, b, 10). line(s3812, s3814, b, 9). line(s3814, s3917, b, 5). line(s3917, s3920, b, 4). line(s3920, s3925, b, 2). line(s3925, s3926, b, 9). line(s3926, s4157, b, 9). line(s4157, s367, b, 5). line(s367, s3927, b, 7). line(s3927, s1788, b, 6). line(s1788, s1789, b, 4). line(s1789, s1049, b, 8). line(s1049, s1050, b, 5). line(s1050, s1052, b, 10). line(s1052, s2133, b, 5). line(s2133, s2135, b, 4). line(s2135, s2038, b, 4). line(s2038, s2040, b, 6). line(s2040, s4768, b, 4). line(s878, s5477, e, 7). line(s5477, s836, e, 7). line(s836, s839, e, 10). line(s839, s882, e, 7). line(s882, s887, e, 15). line(s887, s890, e, 18). line(s890, s1595, e, 15). line(s1595, s1598, e, 18). line(s1598, s1600, e, 12). line(s1600, s1602, e, 9). line(s1602, s1606, e, 20). line(s1606, s1608, e, 6). line(s1608, s1619, e, 8). line(s1619, s1612, e, 6). line(s1619, s3232, e, 22). line(s3232, s3234, e, 13). line(s3234, s3235, e, 6). line(s3235, s1613, e, 10). line(s1613, s3238, e, 15). line(s3238, s3240, e, 14). line(s3240, s5325, e, 6). line(s5325, s3241, e, 8). line(s3241, s3242, e, 8). line(s3242, s4232, e, 6). line(s4232, s3246, e, 19). line(s3246, s3247, e, 6). line(s3247, s3250, e, 7). line(s3250, s3251, e, 9). line(s3251, s3253, e, 10). line(s3253, s3255, e, 9). line(s3255, s3256, e, 7). line(s3256, s4008, e, 5). line(s4008, s4010, e, 6). line(s4010, s4012, e, 4). line(s5426, s4014, e, 3). line(s4014, s4016, e, 6). line(s4016, s4017, e, 5). line(s4017, s5212, e, 4). line(s5212, s5213, e, 6). line(s5213, s2381, e, 3). line(s2381, s5214, e, 9). line(s5214, s5215, e, 9). line(s5215, s2382, e, 9). line(s2382, s2384, e, 9). line(s2384, s2386, e, 3). line(s4086, s4088, e, 10). line(s4088, s4090, e, 8). line(s4090, s4092, e, 8). line(s4092, s4094, e, 6). line(s4094, s4097, e, 10). line(s4097, s4253, e, 14). line(s3184, s3185, e, 2). line(s3185, s3189, e, 9). line(s3189, s3190, e, 7). line(s3190, s3191, e, 10). line(s3191, s3192, e, 6). line(s3192, s3194, e, 10). line(s3194, s3197, e, 9). line(s3197, s3199, e, 12). line(s3199, s3200, e, 2). line(s3200, s3201, e, 10). line(s3201, s3205, e, 12). line(s3205, s1615, e, 18). line(s1615, s3209, e, 15). line(s3209, s3210, e, 12). line(s3210, s3230, e, 12). line(s3230, s1610, e, 13). line(s1610, s1622, e, 23). line(s1622, s1624, e, 18). line(s1624, s1629, e, 22). line(s1629, s1631, e, 6). line(s1631, s1634, e, 12). line(s1634, s904, e, 30). line(s904, s906, e, 33). line(s906, s910, e, 35). line(s910, s843, e, 19). line(s843, s847, e, 8). line(s847, s846, e, 9). line(s367, s3983, w, 4). line(s3983, s367, w, 4). line(s369, s5426, w, 7). line(s5426, s369, w, 7). line(s373, s3061, w, 9). line(s3061, s373, w, 9). line(s381, s2237, w, 4). line(s2237, s381, w, 4). line(s878, s5477, w, 2). line(s5477, s878, w, 2). line(s887, s906, w, 9). line(s906, s887, w, 9). line(s965, s987, w, 9). line(s987, s965, w, 9). line(s974, s979, w, 1). line(s979, s974, w, 1). line(s1049, s1055, w, 6). line(s1055, s1049, w, 6). line(s1050, s1054, w, 3). line(s1054, s1050, w, 3). line(s1051, s1052, w, 5). line(s1052, s1051, w, 5). line(s1595, s1634, w, 7). line(s1634, s1595, w, 7). line(s1598, s1631, w, 6). line(s1631, s1598, w, 6). line(s1600, s1629, w, 7). line(s1629, s1600, w, 7). line(s1610, s1619, w, 8). line(s1619, s1610, w, 8). line(s1788, s3037, w, 7). line(s3037, s1788, w, 7). line(s1789, s3036, w, 6). line(s3036, s1789, w, 6). line(s1791, s4827, w, 6). line(s4827, s1791, w, 6). line(s2038, s2044, w, 6). line(s2044, s2038, w, 6). line(s2133, s2140, w, 3). line(s2140, s2133, w, 3). line(s2135, s2138, w, 7). line(s2138, s2135, w, 7). line(s2223, s3543, w, 6). line(s3543, s2223, w, 6). line(s2228, s3536, w, 7). line(s3536, s2228, w, 7). line(s2231, s3533, w, 5). line(s3533, s2231, w, 5). line(s2384, s5213, w, 8). line(s5213, s2384, w, 8). line(s2387, s2663, w, 6). line(s2663, s2387, w, 6). line(s3050, s3091, w, 7). line(s3091, s3050, w, 7). line(s3056, s3084, w, 9). line(s3084, s3056, w, 9). line(s3066, s3076, w, 5). line(s3076, s3066, w, 5). line(s3069, s3072, w, 6). line(s3072, s3069, w, 6). line(s3070, s3071, w, 5). line(s3071, s3070, w, 5). line(s3189, s3251, w, 4). line(s3251, s3189, w, 4). line(s3190, s3250, w, 5). line(s3250, s3190, w, 5). line(s3192, s3246, w, 5). line(s3246, s3192, w, 5). line(s3194, s3244, w, 6). line(s3244, s3194, w, 6). line(s3195, s4232, w, 7). line(s4232, s3195, w, 7). line(s3197, s3242, w, 5). line(s3242, s3197, w, 5). line(s3199, s3241, w, 5). line(s3241, s3199, w, 5). line(s3209, s3234, w, 7). line(s3234, s3209, w, 7). line(s3210, s3232, w, 6). line(s3232, s3210, w, 6). line(s3362, s3370, w, 9). line(s3370, s3362, w, 9). line(s3413, s3450, w, 3). line(s3450, s3413, w, 3). line(s3416, s3447, w, 5). line(s3447, s3416, w, 5). line(s3420, s3442, w, 7). line(s3442, s3420, w, 7). line(s3546, s5401, w, 8). line(s5401, s3546, w, 8). line(s3549, s3573, w, 7). line(s3573, s3549, w, 7). line(s3559, s3562, w, 6). line(s3562, s3559, w, 6). line(s3917, s3992, w, 4). line(s3992, s3917, w, 4). line(s3920, s3989, w, 9). line(s3989, s3920, w, 9). line(s3926, s3984, w, 9). line(s3984, s3926, w, 9). line(s4006, s4099, w, 5). line(s4099, s4006, w, 5). line(s4216, s4291, w, 4). line(s4291, s4216, w, 4). line(s4218, s4222, w, 9). line(s4222, s4218, w, 9).

start(s3820).
end(s4099).

0 { selected(X,Y,Z) } 1 :- line(X,Y,Z,_).

path(X,Y) :- selected(X,Y,_).
path(X,Z) :- path(X,Y), path(Y,Z).
path(X, Z, W) :- path(X, Y, W), path(Y, Z, W).

:- start(X), end(Y), not path(X,Y).

cost(C) :- C = #count { X,Y,Z : selected(X,Y,Z) }.

#minimize { C : cost(C) }.

#show selected/3.
"""

with open('program3.lp', 'w') as file:
    file.write(code)

# %%
# !clingo program3.lp
# Out:
# clingo version 5.7.1 (849f282)
# Reading from program3.lp
# Solving...
# Answer: 1
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s2663,s3533,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3543,s3545,a) selected(s3549,s3550,a) selected(s3550,s3551,a) selected(s3553,s3555,a) selected(s3559,s3562,a) selected(s3562,s2763,a) selected(s2763,s2843,a) selected(s2843,s2845,a) selected(s2612,s2614,a) selected(s2614,s2618,a) selected(s2622,s2850,a) selected(s5309,s4774,a) selected(s3767,s3768,a) selected(s3728,s3729,d) selected(s3729,s2898,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s981,s3200,c) selected(s3244,s3246,c) selected(s982,s983,c) selected(s985,s987,c) selected(s987,s1676,c) selected(s1676,s3256,c) selected(s4008,s4012,c) selected(s1335,s1339,c) selected(s1341,s1343,c) selected(s3364,s4222,c) selected(s4222,s3413,c) selected(s3413,s3416,c) selected(s3416,s3417,c) selected(s3419,s3420,c) selected(s3032,s3033,c) selected(s3070,s4291,c) selected(s4291,s4567,c) selected(s3586,s1906,c) selected(s3585,s4567,c) selected(s4567,s4216,c) selected(s2712,s2713,c) selected(s3442,s3444,c) selected(s3450,s4218,c) selected(s4218,s3368,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s2138,s2140,b) selected(s1051,s1054,b) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s4099,s4101,b) selected(s373,s3083,b) selected(s3083,s3084,b) selected(s3095,s3097,b) selected(s1671,s2031,b) selected(s2476,s2477,b) selected(s1887,s3044,b) selected(s3053,s3056,b) selected(s3061,s3066,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2223,s2228,b) selected(s2240,s3812,b) selected(s3926,s4157,b) selected(s4157,s367,b) selected(s3927,s1788,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s2038,s2040,b) selected(s878,s5477,e) selected(s839,s882,e) selected(s882,s887,e) selected(s1600,s1602,e) selected(s1619,s1612,e) selected(s3234,s3235,e) selected(s3238,s3240,e) selected(s3242,s4232,e) selected(s3246,s3247,e) selected(s3250,s3251,e) selected(s4008,s4010,e) selected(s2384,s2386,e) selected(s4086,s4088,e) selected(s4088,s4090,e) selected(s4097,s4253,e) selected(s3185,s3189,e) selected(s3190,s3191,e) selected(s3191,s3192,e) selected(s3197,s3199,e) selected(s3209,s3210,e) selected(s906,s910,e) selected(s3061,s373,w) selected(s381,s2237,w) selected(s2237,s381,w) selected(s965,s987,w) selected(s974,s979,w) selected(s1631,s1598,w) selected(s2223,s3543,w) selected(s2228,s3536,w) selected(s2231,s3533,w) selected(s2387,s2663,w) selected(s2663,s2387,w) selected(s3050,s3091,w) selected(s3056,s3084,w) selected(s3084,s3056,w) selected(s3066,s3076,w) selected(s3076,s3066,w) selected(s3069,s3072,w) selected(s3072,s3069,w) selected(s3070,s3071,w) selected(s3189,s3251,w) selected(s3251,s3189,w) selected(s3190,s3250,w) selected(s3250,s3190,w) selected(s3192,s3246,w) selected(s3246,s3192,w) selected(s3244,s3194,w) selected(s3195,s4232,w) selected(s4232,s3195,w) selected(s3197,s3242,w) selected(s3242,s3197,w) selected(s3199,s3241,w) selected(s3241,s3199,w) selected(s3209,s3234,w) selected(s3234,s3209,w) selected(s3210,s3232,w) selected(s3232,s3210,w) selected(s3362,s3370,w) selected(s3370,s3362,w) selected(s3413,s3450,w) selected(s3450,s3413,w) selected(s3416,s3447,w) selected(s3447,s3416,w) selected(s3420,s3442,w) selected(s3546,s5401,w) selected(s5401,s3546,w) selected(s3549,s3573,w) selected(s3559,s3562,w) selected(s3562,s3559,w) selected(s3992,s3917,w) selected(s3926,s3984,w) selected(s4006,s4099,w) selected(s4099,s4006,w) selected(s4216,s4291,w) selected(s4291,s4216,w) selected(s4218,s4222,w) selected(s4222,s4218,w)
# Optimization: 153
# Answer: 2
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s2663,s3533,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3543,s3545,a) selected(s3549,s3550,a) selected(s3550,s3551,a) selected(s3553,s3555,a) selected(s3559,s3562,a) selected(s3562,s2763,a) selected(s2763,s2843,a) selected(s2843,s2845,a) selected(s2612,s2614,a) selected(s2614,s2618,a) selected(s2622,s2850,a) selected(s5309,s4774,a) selected(s3767,s3768,a) selected(s3728,s3729,d) selected(s3729,s2898,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s981,s3200,c) selected(s3244,s3246,c) selected(s982,s983,c) selected(s985,s987,c) selected(s987,s1676,c) selected(s1676,s3256,c) selected(s4008,s4012,c) selected(s1335,s1339,c) selected(s1341,s1343,c) selected(s3364,s4222,c) selected(s4222,s3413,c) selected(s3413,s3416,c) selected(s3416,s3417,c) selected(s3419,s3420,c) selected(s3032,s3033,c) selected(s3070,s4291,c) selected(s4291,s4567,c) selected(s3586,s1906,c) selected(s3585,s4567,c) selected(s4567,s4216,c) selected(s2712,s2713,c) selected(s3442,s3444,c) selected(s3450,s4218,c) selected(s4218,s3368,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s2138,s2140,b) selected(s1051,s1054,b) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s4099,s4101,b) selected(s373,s3083,b) selected(s3083,s3084,b) selected(s3095,s3097,b) selected(s1671,s2031,b) selected(s2476,s2477,b) selected(s1887,s3044,b) selected(s3053,s3056,b) selected(s3061,s3066,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2223,s2228,b) selected(s2240,s3812,b) selected(s3926,s4157,b) selected(s4157,s367,b) selected(s3927,s1788,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s2038,s2040,b) selected(s878,s5477,e) selected(s839,s882,e) selected(s882,s887,e) selected(s1600,s1602,e) selected(s1619,s1612,e) selected(s3234,s3235,e) selected(s3238,s3240,e) selected(s3242,s4232,e) selected(s3246,s3247,e) selected(s3250,s3251,e) selected(s4008,s4010,e) selected(s2384,s2386,e) selected(s4086,s4088,e) selected(s4088,s4090,e) selected(s4097,s4253,e) selected(s3185,s3189,e) selected(s3190,s3191,e) selected(s3191,s3192,e) selected(s3197,s3199,e) selected(s3209,s3210,e) selected(s906,s910,e) selected(s3061,s373,w) selected(s381,s2237,w) selected(s2237,s381,w) selected(s965,s987,w) selected(s974,s979,w) selected(s1631,s1598,w) selected(s2223,s3543,w) selected(s2228,s3536,w) selected(s2231,s3533,w) selected(s2387,s2663,w) selected(s2663,s2387,w) selected(s3050,s3091,w) selected(s3056,s3084,w) selected(s3084,s3056,w) selected(s3066,s3076,w) selected(s3076,s3066,w) selected(s3069,s3072,w) selected(s3072,s3069,w) selected(s3070,s3071,w) selected(s3251,s3189,w) selected(s3190,s3250,w) selected(s3250,s3190,w) selected(s3246,s3192,w) selected(s3194,s3244,w) selected(s3244,s3194,w) selected(s3195,s4232,w) selected(s4232,s3195,w) selected(s3242,s3197,w) selected(s3199,s3241,w) selected(s3241,s3199,w) selected(s3209,s3234,w) selected(s3234,s3209,w) selected(s3210,s3232,w) selected(s3362,s3370,w) selected(s3370,s3362,w) selected(s3413,s3450,w) selected(s3450,s3413,w) selected(s3447,s3416,w) selected(s3420,s3442,w) selected(s3442,s3420,w) selected(s3546,s5401,w) selected(s5401,s3546,w) selected(s3549,s3573,w) selected(s3573,s3549,w) selected(s3559,s3562,w) selected(s3562,s3559,w) selected(s3992,s3917,w) selected(s3926,s3984,w) selected(s4006,s4099,w) selected(s4099,s4006,w) selected(s4216,s4291,w) selected(s4291,s4216,w) selected(s4218,s4222,w) selected(s4222,s4218,w)
# Optimization: 151
# Answer: 3
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s2663,s3533,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3543,s3545,a) selected(s3549,s3550,a) selected(s3550,s3551,a) selected(s3553,s3555,a) selected(s3559,s3562,a) selected(s3562,s2763,a) selected(s2763,s2843,a) selected(s2843,s2845,a) selected(s2612,s2614,a) selected(s2614,s2618,a) selected(s2622,s2850,a) selected(s5309,s4774,a) selected(s3767,s3768,a) selected(s3728,s3729,d) selected(s3729,s2898,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s981,s3200,c) selected(s3244,s3246,c) selected(s982,s983,c) selected(s985,s987,c) selected(s987,s1676,c) selected(s1676,s3256,c) selected(s4008,s4012,c) selected(s1335,s1339,c) selected(s1341,s1343,c) selected(s3364,s4222,c) selected(s4222,s3413,c) selected(s3413,s3416,c) selected(s3416,s3417,c) selected(s3419,s3420,c) selected(s3032,s3033,c) selected(s3070,s4291,c) selected(s4291,s4567,c) selected(s3586,s1906,c) selected(s3585,s4567,c) selected(s4567,s4216,c) selected(s2712,s2713,c) selected(s3442,s3444,c) selected(s3450,s4218,c) selected(s4218,s3368,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s2138,s2140,b) selected(s1051,s1054,b) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s4099,s4101,b) selected(s373,s3083,b) selected(s3083,s3084,b) selected(s3095,s3097,b) selected(s1671,s2031,b) selected(s2476,s2477,b) selected(s1887,s3044,b) selected(s3053,s3056,b) selected(s3061,s3066,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2223,s2228,b) selected(s2240,s3812,b) selected(s3926,s4157,b) selected(s4157,s367,b) selected(s3927,s1788,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s2038,s2040,b) selected(s878,s5477,e) selected(s839,s882,e) selected(s882,s887,e) selected(s1600,s1602,e) selected(s1619,s1612,e) selected(s3234,s3235,e) selected(s3238,s3240,e) selected(s3242,s4232,e) selected(s3246,s3247,e) selected(s3250,s3251,e) selected(s4008,s4010,e) selected(s2384,s2386,e) selected(s4086,s4088,e) selected(s4088,s4090,e) selected(s4097,s4253,e) selected(s3185,s3189,e) selected(s3190,s3191,e) selected(s3191,s3192,e) selected(s3197,s3199,e) selected(s3209,s3210,e) selected(s906,s910,e) selected(s3061,s373,w) selected(s381,s2237,w) selected(s2237,s381,w) selected(s965,s987,w) selected(s974,s979,w) selected(s1631,s1598,w) selected(s2223,s3543,w) selected(s2228,s3536,w) selected(s2231,s3533,w) selected(s2387,s2663,w) selected(s2663,s2387,w) selected(s3050,s3091,w) selected(s3056,s3084,w) selected(s3084,s3056,w) selected(s3066,s3076,w) selected(s3076,s3066,w) selected(s3069,s3072,w) selected(s3072,s3069,w) selected(s3070,s3071,w) selected(s3251,s3189,w) selected(s3190,s3250,w) selected(s3250,s3190,w) selected(s3246,s3192,w) selected(s3244,s3194,w) selected(s3195,s4232,w) selected(s4232,s3195,w) selected(s3197,s3242,w) selected(s3242,s3197,w) selected(s3199,s3241,w) selected(s3241,s3199,w) selected(s3209,s3234,w) selected(s3234,s3209,w) selected(s3210,s3232,w) selected(s3232,s3210,w) selected(s3362,s3370,w) selected(s3370,s3362,w) selected(s3450,s3413,w) selected(s3447,s3416,w) selected(s3420,s3442,w) selected(s3442,s3420,w) selected(s3546,s5401,w) selected(s5401,s3546,w) selected(s3549,s3573,w) selected(s3573,s3549,w) selected(s3559,s3562,w) selected(s3562,s3559,w) selected(s3992,s3917,w) selected(s3926,s3984,w) selected(s4006,s4099,w) selected(s4216,s4291,w) selected(s4291,s4216,w) selected(s4218,s4222,w) selected(s4222,s4218,w)
# Optimization: 150
# Answer: 4
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s2663,s3533,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3543,s3545,a) selected(s3549,s3550,a) selected(s3550,s3551,a) selected(s3553,s3555,a) selected(s3559,s3562,a) selected(s3562,s2763,a) selected(s2763,s2843,a) selected(s2843,s2845,a) selected(s2612,s2614,a) selected(s2614,s2618,a) selected(s2622,s2850,a) selected(s5309,s4774,a) selected(s3767,s3768,a) selected(s3728,s3729,d) selected(s3729,s2898,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s981,s3200,c) selected(s3244,s3246,c) selected(s982,s983,c) selected(s985,s987,c) selected(s987,s1676,c) selected(s1676,s3256,c) selected(s4008,s4012,c) selected(s1335,s1339,c) selected(s1341,s1343,c) selected(s3364,s4222,c) selected(s4222,s3413,c) selected(s3413,s3416,c) selected(s3416,s3417,c) selected(s3419,s3420,c) selected(s3032,s3033,c) selected(s3070,s4291,c) selected(s4291,s4567,c) selected(s3586,s1906,c) selected(s3585,s4567,c) selected(s4567,s4216,c) selected(s2712,s2713,c) selected(s3442,s3444,c) selected(s3450,s4218,c) selected(s4218,s3368,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s2138,s2140,b) selected(s1051,s1054,b) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s4099,s4101,b) selected(s373,s3083,b) selected(s3083,s3084,b) selected(s3095,s3097,b) selected(s1671,s2031,b) selected(s2476,s2477,b) selected(s1887,s3044,b) selected(s3053,s3056,b) selected(s3061,s3066,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2223,s2228,b) selected(s2240,s3812,b) selected(s3926,s4157,b) selected(s4157,s367,b) selected(s3927,s1788,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s2038,s2040,b) selected(s878,s5477,e) selected(s839,s882,e) selected(s882,s887,e) selected(s1600,s1602,e) selected(s1619,s1612,e) selected(s3234,s3235,e) selected(s3238,s3240,e) selected(s3242,s4232,e) selected(s3246,s3247,e) selected(s3250,s3251,e) selected(s4008,s4010,e) selected(s2384,s2386,e) selected(s4086,s4088,e) selected(s4088,s4090,e) selected(s4097,s4253,e) selected(s3185,s3189,e) selected(s3190,s3191,e) selected(s3191,s3192,e) selected(s3197,s3199,e) selected(s3209,s3210,e) selected(s906,s910,e) selected(s3061,s373,w) selected(s381,s2237,w) selected(s2237,s381,w) selected(s965,s987,w) selected(s974,s979,w) selected(s1631,s1598,w) selected(s2223,s3543,w) selected(s2228,s3536,w) selected(s2231,s3533,w) selected(s2387,s2663,w) selected(s2663,s2387,w) selected(s3050,s3091,w) selected(s3056,s3084,w) selected(s3084,s3056,w) selected(s3066,s3076,w) selected(s3076,s3066,w) selected(s3069,s3072,w) selected(s3072,s3069,w) selected(s3070,s3071,w) selected(s3251,s3189,w) selected(s3190,s3250,w) selected(s3250,s3190,w) selected(s3246,s3192,w) selected(s3195,s4232,w) selected(s4232,s3195,w) selected(s3242,s3197,w) selected(s3199,s3241,w) selected(s3241,s3199,w) selected(s3209,s3234,w) selected(s3234,s3209,w) selected(s3210,s3232,w) selected(s3232,s3210,w) selected(s3362,s3370,w) selected(s3413,s3450,w) selected(s3450,s3413,w) selected(s3447,s3416,w) selected(s3420,s3442,w) selected(s3442,s3420,w) selected(s3546,s5401,w) selected(s5401,s3546,w) selected(s3549,s3573,w) selected(s3573,s3549,w) selected(s3559,s3562,w) selected(s3562,s3559,w) selected(s3992,s3917,w) selected(s3926,s3984,w) selected(s4006,s4099,w) selected(s4099,s4006,w) selected(s4216,s4291,w) selected(s4291,s4216,w) selected(s4218,s4222,w) selected(s4222,s4218,w)
# Optimization: 149
# Answer: 5
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s2663,s3533,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3543,s3545,a) selected(s3549,s3550,a) selected(s3550,s3551,a) selected(s3553,s3555,a) selected(s3559,s3562,a) selected(s3562,s2763,a) selected(s2763,s2843,a) selected(s2843,s2845,a) selected(s2612,s2614,a) selected(s2614,s2618,a) selected(s2622,s2850,a) selected(s5309,s4774,a) selected(s3767,s3768,a) selected(s3728,s3729,d) selected(s3729,s2898,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s981,s3200,c) selected(s3244,s3246,c) selected(s982,s983,c) selected(s985,s987,c) selected(s987,s1676,c) selected(s1676,s3256,c) selected(s4008,s4012,c) selected(s1335,s1339,c) selected(s1341,s1343,c) selected(s3364,s4222,c) selected(s4222,s3413,c) selected(s3413,s3416,c) selected(s3416,s3417,c) selected(s3419,s3420,c) selected(s3032,s3033,c) selected(s3070,s4291,c) selected(s4291,s4567,c) selected(s3586,s1906,c) selected(s3585,s4567,c) selected(s4567,s4216,c) selected(s2712,s2713,c) selected(s3442,s3444,c) selected(s3450,s4218,c) selected(s4218,s3368,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s2138,s2140,b) selected(s1051,s1054,b) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s4099,s4101,b) selected(s373,s3083,b) selected(s3083,s3084,b) selected(s3095,s3097,b) selected(s1671,s2031,b) selected(s2476,s2477,b) selected(s1887,s3044,b) selected(s3053,s3056,b) selected(s3061,s3066,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2223,s2228,b) selected(s2240,s3812,b) selected(s3926,s4157,b) selected(s4157,s367,b) selected(s3927,s1788,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s2038,s2040,b) selected(s878,s5477,e) selected(s839,s882,e) selected(s882,s887,e) selected(s1600,s1602,e) selected(s1619,s1612,e) selected(s3234,s3235,e) selected(s3238,s3240,e) selected(s3242,s4232,e) selected(s3246,s3247,e) selected(s3250,s3251,e) selected(s4008,s4010,e) selected(s2384,s2386,e) selected(s4086,s4088,e) selected(s4088,s4090,e) selected(s4097,s4253,e) selected(s3185,s3189,e) selected(s3190,s3191,e) selected(s3191,s3192,e) selected(s3197,s3199,e) selected(s3209,s3210,e) selected(s906,s910,e) selected(s3061,s373,w) selected(s381,s2237,w) selected(s2237,s381,w) selected(s965,s987,w) selected(s974,s979,w) selected(s1631,s1598,w) selected(s2223,s3543,w) selected(s2228,s3536,w) selected(s2231,s3533,w) selected(s2387,s2663,w) selected(s2663,s2387,w) selected(s3050,s3091,w) selected(s3056,s3084,w) selected(s3084,s3056,w) selected(s3066,s3076,w) selected(s3076,s3066,w) selected(s3069,s3072,w) selected(s3072,s3069,w) selected(s3070,s3071,w) selected(s3251,s3189,w) selected(s3190,s3250,w) selected(s3250,s3190,w) selected(s3246,s3192,w) selected(s3195,s4232,w) selected(s4232,s3195,w) selected(s3197,s3242,w) selected(s3199,s3241,w) selected(s3241,s3199,w) selected(s3209,s3234,w) selected(s3234,s3209,w) selected(s3362,s3370,w) selected(s3413,s3450,w) selected(s3450,s3413,w) selected(s3447,s3416,w) selected(s3420,s3442,w) selected(s3442,s3420,w) selected(s3546,s5401,w) selected(s5401,s3546,w) selected(s3549,s3573,w) selected(s3573,s3549,w) selected(s3559,s3562,w) selected(s3562,s3559,w) selected(s3992,s3917,w) selected(s3926,s3984,w) selected(s4006,s4099,w) selected(s4099,s4006,w) selected(s4216,s4291,w) selected(s4291,s4216,w) selected(s4222,s4218,w)
# Optimization: 146
# Answer: 6
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s2663,s3533,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3543,s3545,a) selected(s3549,s3550,a) selected(s3550,s3551,a) selected(s3553,s3555,a) selected(s3559,s3562,a) selected(s3562,s2763,a) selected(s2763,s2843,a) selected(s2843,s2845,a) selected(s2612,s2614,a) selected(s2614,s2618,a) selected(s2622,s2850,a) selected(s5309,s4774,a) selected(s3767,s3768,a) selected(s3728,s3729,d) selected(s3729,s2898,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s981,s3200,c) selected(s3244,s3246,c) selected(s982,s983,c) selected(s985,s987,c) selected(s987,s1676,c) selected(s1676,s3256,c) selected(s4008,s4012,c) selected(s1335,s1339,c) selected(s1341,s1343,c) selected(s3364,s4222,c) selected(s4222,s3413,c) selected(s3413,s3416,c) selected(s3416,s3417,c) selected(s3419,s3420,c) selected(s3032,s3033,c) selected(s3070,s4291,c) selected(s4291,s4567,c) selected(s3586,s1906,c) selected(s3585,s4567,c) selected(s4567,s4216,c) selected(s2712,s2713,c) selected(s3442,s3444,c) selected(s3450,s4218,c) selected(s4218,s3368,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s2138,s2140,b) selected(s1051,s1054,b) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s4099,s4101,b) selected(s373,s3083,b) selected(s3083,s3084,b) selected(s3095,s3097,b) selected(s1671,s2031,b) selected(s2476,s2477,b) selected(s1887,s3044,b) selected(s3053,s3056,b) selected(s3061,s3066,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2223,s2228,b) selected(s2240,s3812,b) selected(s3926,s4157,b) selected(s4157,s367,b) selected(s3927,s1788,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s2038,s2040,b) selected(s878,s5477,e) selected(s839,s882,e) selected(s882,s887,e) selected(s1600,s1602,e) selected(s1619,s1612,e) selected(s3234,s3235,e) selected(s3238,s3240,e) selected(s3242,s4232,e) selected(s3246,s3247,e) selected(s3250,s3251,e) selected(s4008,s4010,e) selected(s2384,s2386,e) selected(s4086,s4088,e) selected(s4088,s4090,e) selected(s4097,s4253,e) selected(s3185,s3189,e) selected(s3190,s3191,e) selected(s3191,s3192,e) selected(s3197,s3199,e) selected(s3209,s3210,e) selected(s906,s910,e) selected(s3061,s373,w) selected(s381,s2237,w) selected(s2237,s381,w) selected(s965,s987,w) selected(s974,s979,w) selected(s1631,s1598,w) selected(s2223,s3543,w) selected(s2228,s3536,w) selected(s2231,s3533,w) selected(s2387,s2663,w) selected(s2663,s2387,w) selected(s3050,s3091,w) selected(s3056,s3084,w) selected(s3084,s3056,w) selected(s3066,s3076,w) selected(s3076,s3066,w) selected(s3069,s3072,w) selected(s3070,s3071,w) selected(s3251,s3189,w) selected(s3190,s3250,w) selected(s3250,s3190,w) selected(s3246,s3192,w) selected(s3195,s4232,w) selected(s4232,s3195,w) selected(s3199,s3241,w) selected(s3241,s3199,w) selected(s3209,s3234,w) selected(s3234,s3209,w) selected(s3210,s3232,w) selected(s3362,s3370,w) selected(s3413,s3450,w) selected(s3450,s3413,w) selected(s3447,s3416,w) selected(s3420,s3442,w) selected(s3546,s5401,w) selected(s5401,s3546,w) selected(s3549,s3573,w) selected(s3573,s3549,w) selected(s3559,s3562,w) selected(s3562,s3559,w) selected(s3992,s3917,w) selected(s3926,s3984,w) selected(s4006,s4099,w) selected(s4099,s4006,w) selected(s4216,s4291,w) selected(s4291,s4216,w) selected(s4218,s4222,w) selected(s4222,s4218,w)
# Optimization: 145
# Answer: 7
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s2663,s3533,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3543,s3545,a) selected(s3549,s3550,a) selected(s3550,s3551,a) selected(s3553,s3555,a) selected(s3559,s3562,a) selected(s3562,s2763,a) selected(s2763,s2843,a) selected(s2843,s2845,a) selected(s2612,s2614,a) selected(s2614,s2618,a) selected(s2622,s2850,a) selected(s5309,s4774,a) selected(s3767,s3768,a) selected(s3728,s3729,d) selected(s3729,s2898,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s981,s3200,c) selected(s3244,s3246,c) selected(s982,s983,c) selected(s985,s987,c) selected(s987,s1676,c) selected(s1676,s3256,c) selected(s4008,s4012,c) selected(s1335,s1339,c) selected(s1341,s1343,c) selected(s3364,s4222,c) selected(s4222,s3413,c) selected(s3413,s3416,c) selected(s3416,s3417,c) selected(s3419,s3420,c) selected(s3032,s3033,c) selected(s3070,s4291,c) selected(s4291,s4567,c) selected(s3586,s1906,c) selected(s3585,s4567,c) selected(s4567,s4216,c) selected(s2712,s2713,c) selected(s3442,s3444,c) selected(s3450,s4218,c) selected(s4218,s3368,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s2138,s2140,b) selected(s1051,s1054,b) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s4099,s4101,b) selected(s373,s3083,b) selected(s3083,s3084,b) selected(s3095,s3097,b) selected(s1671,s2031,b) selected(s2476,s2477,b) selected(s1887,s3044,b) selected(s3053,s3056,b) selected(s3061,s3066,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2223,s2228,b) selected(s2240,s3812,b) selected(s3926,s4157,b) selected(s4157,s367,b) selected(s3927,s1788,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s2038,s2040,b) selected(s878,s5477,e) selected(s839,s882,e) selected(s882,s887,e) selected(s1600,s1602,e) selected(s1619,s1612,e) selected(s3234,s3235,e) selected(s3238,s3240,e) selected(s3242,s4232,e) selected(s3246,s3247,e) selected(s3250,s3251,e) selected(s4008,s4010,e) selected(s2384,s2386,e) selected(s4086,s4088,e) selected(s4088,s4090,e) selected(s4097,s4253,e) selected(s3185,s3189,e) selected(s3190,s3191,e) selected(s3191,s3192,e) selected(s3197,s3199,e) selected(s3209,s3210,e) selected(s906,s910,e) selected(s3061,s373,w) selected(s381,s2237,w) selected(s2237,s381,w) selected(s965,s987,w) selected(s974,s979,w) selected(s1631,s1598,w) selected(s2223,s3543,w) selected(s2228,s3536,w) selected(s2231,s3533,w) selected(s2387,s2663,w) selected(s2663,s2387,w) selected(s3050,s3091,w) selected(s3056,s3084,w) selected(s3084,s3056,w) selected(s3066,s3076,w) selected(s3076,s3066,w) selected(s3069,s3072,w) selected(s3070,s3071,w) selected(s3190,s3250,w) selected(s3250,s3190,w) selected(s3246,s3192,w) selected(s3195,s4232,w) selected(s4232,s3195,w) selected(s3241,s3199,w) selected(s3234,s3209,w) selected(s3210,s3232,w) selected(s3362,s3370,w) selected(s3413,s3450,w) selected(s3447,s3416,w) selected(s3442,s3420,w) selected(s3546,s5401,w) selected(s5401,s3546,w) selected(s3549,s3573,w) selected(s3559,s3562,w) selected(s3992,s3917,w) selected(s3926,s3984,w) selected(s4099,s4006,w) selected(s4216,s4291,w) selected(s4291,s4216,w) selected(s4218,s4222,w) selected(s4222,s4218,w)
# Optimization: 138
# Answer: 8
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s2663,s3533,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3543,s3545,a) selected(s3549,s3550,a) selected(s3550,s3551,a) selected(s3553,s3555,a) selected(s3559,s3562,a) selected(s3562,s2763,a) selected(s2763,s2843,a) selected(s2843,s2845,a) selected(s2612,s2614,a) selected(s2614,s2618,a) selected(s2622,s2850,a) selected(s5309,s4774,a) selected(s3767,s3768,a) selected(s3728,s3729,d) selected(s3729,s2898,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s981,s3200,c) selected(s3244,s3246,c) selected(s982,s983,c) selected(s985,s987,c) selected(s987,s1676,c) selected(s1676,s3256,c) selected(s4008,s4012,c) selected(s1335,s1339,c) selected(s1341,s1343,c) selected(s3364,s4222,c) selected(s4222,s3413,c) selected(s3413,s3416,c) selected(s3416,s3417,c) selected(s3419,s3420,c) selected(s3032,s3033,c) selected(s3070,s4291,c) selected(s4291,s4567,c) selected(s3586,s1906,c) selected(s3585,s4567,c) selected(s4567,s4216,c) selected(s2712,s2713,c) selected(s3442,s3444,c) selected(s3450,s4218,c) selected(s4218,s3368,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s2138,s2140,b) selected(s1051,s1054,b) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s4099,s4101,b) selected(s373,s3083,b) selected(s3083,s3084,b) selected(s3095,s3097,b) selected(s1671,s2031,b) selected(s2476,s2477,b) selected(s1887,s3044,b) selected(s3053,s3056,b) selected(s3061,s3066,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2223,s2228,b) selected(s2240,s3812,b) selected(s3926,s4157,b) selected(s4157,s367,b) selected(s3927,s1788,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s2038,s2040,b) selected(s878,s5477,e) selected(s839,s882,e) selected(s882,s887,e) selected(s1600,s1602,e) selected(s1619,s1612,e) selected(s3234,s3235,e) selected(s3238,s3240,e) selected(s3242,s4232,e) selected(s3246,s3247,e) selected(s3250,s3251,e) selected(s4008,s4010,e) selected(s2384,s2386,e) selected(s4086,s4088,e) selected(s4088,s4090,e) selected(s4097,s4253,e) selected(s3185,s3189,e) selected(s3190,s3191,e) selected(s3191,s3192,e) selected(s3197,s3199,e) selected(s3209,s3210,e) selected(s906,s910,e) selected(s3061,s373,w) selected(s381,s2237,w) selected(s2237,s381,w) selected(s965,s987,w) selected(s974,s979,w) selected(s1631,s1598,w) selected(s2223,s3543,w) selected(s2228,s3536,w) selected(s2231,s3533,w) selected(s2387,s2663,w) selected(s2663,s2387,w) selected(s3050,s3091,w) selected(s3056,s3084,w) selected(s3084,s3056,w) selected(s3066,s3076,w) selected(s3076,s3066,w) selected(s3069,s3072,w) selected(s3070,s3071,w) selected(s3190,s3250,w) selected(s3250,s3190,w) selected(s3195,s4232,w) selected(s4232,s3195,w) selected(s3199,s3241,w) selected(s3241,s3199,w) selected(s3234,s3209,w) selected(s3210,s3232,w) selected(s3362,s3370,w) selected(s3413,s3450,w) selected(s3447,s3416,w) selected(s3442,s3420,w) selected(s3546,s5401,w) selected(s5401,s3546,w) selected(s3549,s3573,w) selected(s3559,s3562,w) selected(s3992,s3917,w) selected(s3926,s3984,w) selected(s4099,s4006,w) selected(s4216,s4291,w) selected(s4218,s4222,w) selected(s4222,s4218,w)
# Optimization: 137
# Answer: 9
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s2663,s3533,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3543,s3545,a) selected(s3549,s3550,a) selected(s3550,s3551,a) selected(s3553,s3555,a) selected(s3559,s3562,a) selected(s3562,s2763,a) selected(s2763,s2843,a) selected(s2843,s2845,a) selected(s2612,s2614,a) selected(s2614,s2618,a) selected(s2622,s2850,a) selected(s5309,s4774,a) selected(s3767,s3768,a) selected(s3728,s3729,d) selected(s3729,s2898,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s981,s3200,c) selected(s3244,s3246,c) selected(s982,s983,c) selected(s985,s987,c) selected(s987,s1676,c) selected(s1676,s3256,c) selected(s4008,s4012,c) selected(s1335,s1339,c) selected(s1341,s1343,c) selected(s3364,s4222,c) selected(s4222,s3413,c) selected(s3413,s3416,c) selected(s3416,s3417,c) selected(s3419,s3420,c) selected(s3032,s3033,c) selected(s3070,s4291,c) selected(s4291,s4567,c) selected(s3586,s1906,c) selected(s3585,s4567,c) selected(s4567,s4216,c) selected(s2712,s2713,c) selected(s3442,s3444,c) selected(s3450,s4218,c) selected(s4218,s3368,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s2138,s2140,b) selected(s1051,s1054,b) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s4099,s4101,b) selected(s373,s3083,b) selected(s3083,s3084,b) selected(s3095,s3097,b) selected(s1671,s2031,b) selected(s2476,s2477,b) selected(s1887,s3044,b) selected(s3053,s3056,b) selected(s3061,s3066,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2223,s2228,b) selected(s2240,s3812,b) selected(s3926,s4157,b) selected(s4157,s367,b) selected(s3927,s1788,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s2038,s2040,b) selected(s878,s5477,e) selected(s839,s882,e) selected(s882,s887,e) selected(s1600,s1602,e) selected(s1619,s1612,e) selected(s3234,s3235,e) selected(s3238,s3240,e) selected(s3242,s4232,e) selected(s3246,s3247,e) selected(s3250,s3251,e) selected(s4008,s4010,e) selected(s2384,s2386,e) selected(s4086,s4088,e) selected(s4088,s4090,e) selected(s4097,s4253,e) selected(s3185,s3189,e) selected(s3190,s3191,e) selected(s3191,s3192,e) selected(s3197,s3199,e) selected(s3209,s3210,e) selected(s906,s910,e) selected(s3061,s373,w) selected(s381,s2237,w) selected(s2237,s381,w) selected(s965,s987,w) selected(s974,s979,w) selected(s1631,s1598,w) selected(s2223,s3543,w) selected(s2228,s3536,w) selected(s2231,s3533,w) selected(s2387,s2663,w) selected(s2663,s2387,w) selected(s3050,s3091,w) selected(s3056,s3084,w) selected(s3066,s3076,w) selected(s3076,s3066,w) selected(s3069,s3072,w) selected(s3070,s3071,w) selected(s3190,s3250,w) selected(s3250,s3190,w) selected(s3246,s3192,w) selected(s3195,s4232,w) selected(s4232,s3195,w) selected(s3241,s3199,w) selected(s3234,s3209,w) selected(s3210,s3232,w) selected(s3362,s3370,w) selected(s3413,s3450,w) selected(s3447,s3416,w) selected(s3546,s5401,w) selected(s5401,s3546,w) selected(s3549,s3573,w) selected(s3559,s3562,w) selected(s3992,s3917,w) selected(s3926,s3984,w) selected(s4099,s4006,w) selected(s4216,s4291,w) selected(s4291,s4216,w) selected(s4218,s4222,w) selected(s4222,s4218,w)
# Optimization: 136
# Answer: 10
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s2663,s3533,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3543,s3545,a) selected(s3549,s3550,a) selected(s3550,s3551,a) selected(s3553,s3555,a) selected(s3559,s3562,a) selected(s3562,s2763,a) selected(s2763,s2843,a) selected(s2843,s2845,a) selected(s2612,s2614,a) selected(s2614,s2618,a) selected(s2622,s2850,a) selected(s5309,s4774,a) selected(s3767,s3768,a) selected(s3728,s3729,d) selected(s3729,s2898,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s981,s3200,c) selected(s3244,s3246,c) selected(s982,s983,c) selected(s985,s987,c) selected(s987,s1676,c) selected(s1676,s3256,c) selected(s4008,s4012,c) selected(s1335,s1339,c) selected(s1341,s1343,c) selected(s3364,s4222,c) selected(s4222,s3413,c) selected(s3413,s3416,c) selected(s3416,s3417,c) selected(s3419,s3420,c) selected(s3032,s3033,c) selected(s3070,s4291,c) selected(s4291,s4567,c) selected(s3586,s1906,c) selected(s3585,s4567,c) selected(s4567,s4216,c) selected(s2712,s2713,c) selected(s3442,s3444,c) selected(s3450,s4218,c) selected(s4218,s3368,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s2138,s2140,b) selected(s1051,s1054,b) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s4099,s4101,b) selected(s373,s3083,b) selected(s3083,s3084,b) selected(s3095,s3097,b) selected(s1671,s2031,b) selected(s2476,s2477,b) selected(s1887,s3044,b) selected(s3053,s3056,b) selected(s3061,s3066,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2223,s2228,b) selected(s2240,s3812,b) selected(s3926,s4157,b) selected(s4157,s367,b) selected(s3927,s1788,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s2038,s2040,b) selected(s878,s5477,e) selected(s839,s882,e) selected(s882,s887,e) selected(s1600,s1602,e) selected(s1619,s1612,e) selected(s3234,s3235,e) selected(s3238,s3240,e) selected(s3242,s4232,e) selected(s3246,s3247,e) selected(s3250,s3251,e) selected(s4008,s4010,e) selected(s2384,s2386,e) selected(s4086,s4088,e) selected(s4088,s4090,e) selected(s4097,s4253,e) selected(s3185,s3189,e) selected(s3190,s3191,e) selected(s3191,s3192,e) selected(s3197,s3199,e) selected(s3209,s3210,e) selected(s906,s910,e) selected(s3061,s373,w) selected(s381,s2237,w) selected(s2237,s381,w) selected(s965,s987,w) selected(s974,s979,w) selected(s1631,s1598,w) selected(s2223,s3543,w) selected(s2228,s3536,w) selected(s2231,s3533,w) selected(s2387,s2663,w) selected(s2663,s2387,w) selected(s3050,s3091,w) selected(s3056,s3084,w) selected(s3066,s3076,w) selected(s3076,s3066,w) selected(s3069,s3072,w) selected(s3070,s3071,w) selected(s3190,s3250,w) selected(s3250,s3190,w) selected(s3246,s3192,w) selected(s3195,s4232,w) selected(s4232,s3195,w) selected(s3199,s3241,w) selected(s3241,s3199,w) selected(s3234,s3209,w) selected(s3210,s3232,w) selected(s3362,s3370,w) selected(s3413,s3450,w) selected(s3447,s3416,w) selected(s3546,s5401,w) selected(s5401,s3546,w) selected(s3559,s3562,w) selected(s3992,s3917,w) selected(s4099,s4006,w) selected(s4216,s4291,w) selected(s4291,s4216,w) selected(s4218,s4222,w) selected(s4222,s4218,w)
# Optimization: 135
# Answer: 11
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s2663,s3533,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3543,s3545,a) selected(s3549,s3550,a) selected(s3550,s3551,a) selected(s3553,s3555,a) selected(s3559,s3562,a) selected(s3562,s2763,a) selected(s2763,s2843,a) selected(s2843,s2845,a) selected(s2612,s2614,a) selected(s2614,s2618,a) selected(s2622,s2850,a) selected(s5309,s4774,a) selected(s3767,s3768,a) selected(s3728,s3729,d) selected(s3729,s2898,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s981,s3200,c) selected(s3244,s3246,c) selected(s982,s983,c) selected(s985,s987,c) selected(s987,s1676,c) selected(s1676,s3256,c) selected(s4008,s4012,c) selected(s1335,s1339,c) selected(s1341,s1343,c) selected(s3364,s4222,c) selected(s4222,s3413,c) selected(s3413,s3416,c) selected(s3416,s3417,c) selected(s3419,s3420,c) selected(s3032,s3033,c) selected(s3070,s4291,c) selected(s4291,s4567,c) selected(s3586,s1906,c) selected(s3585,s4567,c) selected(s4567,s4216,c) selected(s2712,s2713,c) selected(s3442,s3444,c) selected(s3450,s4218,c) selected(s4218,s3368,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s2138,s2140,b) selected(s1051,s1054,b) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s4099,s4101,b) selected(s373,s3083,b) selected(s3083,s3084,b) selected(s3095,s3097,b) selected(s1671,s2031,b) selected(s2476,s2477,b) selected(s1887,s3044,b) selected(s3053,s3056,b) selected(s3061,s3066,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2223,s2228,b) selected(s2240,s3812,b) selected(s3926,s4157,b) selected(s4157,s367,b) selected(s3927,s1788,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s2038,s2040,b) selected(s878,s5477,e) selected(s839,s882,e) selected(s882,s887,e) selected(s1600,s1602,e) selected(s1619,s1612,e) selected(s3234,s3235,e) selected(s3238,s3240,e) selected(s3242,s4232,e) selected(s3246,s3247,e) selected(s3250,s3251,e) selected(s4008,s4010,e) selected(s2384,s2386,e) selected(s4086,s4088,e) selected(s4088,s4090,e) selected(s4097,s4253,e) selected(s3185,s3189,e) selected(s3190,s3191,e) selected(s3191,s3192,e) selected(s3197,s3199,e) selected(s3209,s3210,e) selected(s906,s910,e) selected(s3061,s373,w) selected(s381,s2237,w) selected(s2237,s381,w) selected(s965,s987,w) selected(s974,s979,w) selected(s1631,s1598,w) selected(s2223,s3543,w) selected(s2228,s3536,w) selected(s2231,s3533,w) selected(s2387,s2663,w) selected(s2663,s2387,w) selected(s3050,s3091,w) selected(s3056,s3084,w) selected(s3076,s3066,w) selected(s3069,s3072,w) selected(s3070,s3071,w) selected(s3190,s3250,w) selected(s3250,s3190,w) selected(s3246,s3192,w) selected(s3195,s4232,w) selected(s4232,s3195,w) selected(s3199,s3241,w) selected(s3241,s3199,w) selected(s3234,s3209,w) selected(s3210,s3232,w) selected(s3362,s3370,w) selected(s3413,s3450,w) selected(s3447,s3416,w) selected(s3442,s3420,w) selected(s3546,s5401,w) selected(s5401,s3546,w) selected(s3559,s3562,w) selected(s3992,s3917,w) selected(s4099,s4006,w) selected(s4216,s4291,w) selected(s4291,s4216,w) selected(s4218,s4222,w)
# Optimization: 134
# Answer: 12
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s2663,s3533,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3543,s3545,a) selected(s3549,s3550,a) selected(s3550,s3551,a) selected(s3553,s3555,a) selected(s3559,s3562,a) selected(s3562,s2763,a) selected(s2763,s2843,a) selected(s2843,s2845,a) selected(s2612,s2614,a) selected(s2614,s2618,a) selected(s2622,s2850,a) selected(s5309,s4774,a) selected(s3767,s3768,a) selected(s3728,s3729,d) selected(s3729,s2898,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s981,s3200,c) selected(s3244,s3246,c) selected(s982,s983,c) selected(s985,s987,c) selected(s987,s1676,c) selected(s1676,s3256,c) selected(s4008,s4012,c) selected(s1335,s1339,c) selected(s1341,s1343,c) selected(s3364,s4222,c) selected(s4222,s3413,c) selected(s3413,s3416,c) selected(s3416,s3417,c) selected(s3419,s3420,c) selected(s3032,s3033,c) selected(s3070,s4291,c) selected(s4291,s4567,c) selected(s3586,s1906,c) selected(s3585,s4567,c) selected(s4567,s4216,c) selected(s2712,s2713,c) selected(s3442,s3444,c) selected(s3450,s4218,c) selected(s4218,s3368,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s2138,s2140,b) selected(s1051,s1054,b) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s4099,s4101,b) selected(s373,s3083,b) selected(s3083,s3084,b) selected(s3095,s3097,b) selected(s1671,s2031,b) selected(s2476,s2477,b) selected(s1887,s3044,b) selected(s3053,s3056,b) selected(s3061,s3066,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2223,s2228,b) selected(s2240,s3812,b) selected(s3926,s4157,b) selected(s4157,s367,b) selected(s3927,s1788,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s2038,s2040,b) selected(s878,s5477,e) selected(s839,s882,e) selected(s882,s887,e) selected(s1600,s1602,e) selected(s1619,s1612,e) selected(s3234,s3235,e) selected(s3238,s3240,e) selected(s3242,s4232,e) selected(s3246,s3247,e) selected(s3250,s3251,e) selected(s4008,s4010,e) selected(s2384,s2386,e) selected(s4086,s4088,e) selected(s4088,s4090,e) selected(s4097,s4253,e) selected(s3185,s3189,e) selected(s3190,s3191,e) selected(s3191,s3192,e) selected(s3197,s3199,e) selected(s3209,s3210,e) selected(s906,s910,e) selected(s3061,s373,w) selected(s381,s2237,w) selected(s2237,s381,w) selected(s965,s987,w) selected(s974,s979,w) selected(s1631,s1598,w) selected(s2223,s3543,w) selected(s2228,s3536,w) selected(s2231,s3533,w) selected(s2387,s2663,w) selected(s2663,s2387,w) selected(s3050,s3091,w) selected(s3056,s3084,w) selected(s3076,s3066,w) selected(s3069,s3072,w) selected(s3070,s3071,w) selected(s3190,s3250,w) selected(s3250,s3190,w) selected(s3246,s3192,w) selected(s3195,s4232,w) selected(s4232,s3195,w) selected(s3199,s3241,w) selected(s3241,s3199,w) selected(s3234,s3209,w) selected(s3210,s3232,w) selected(s3362,s3370,w) selected(s3413,s3450,w) selected(s3447,s3416,w) selected(s3546,s5401,w) selected(s5401,s3546,w) selected(s3559,s3562,w) selected(s3992,s3917,w) selected(s4099,s4006,w) selected(s4216,s4291,w) selected(s4291,s4216,w) selected(s4218,s4222,w)
# Optimization: 133
# Answer: 13
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s2663,s3533,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3543,s3545,a) selected(s3549,s3550,a) selected(s3550,s3551,a) selected(s3553,s3555,a) selected(s3559,s3562,a) selected(s3562,s2763,a) selected(s2763,s2843,a) selected(s2843,s2845,a) selected(s2612,s2614,a) selected(s2614,s2618,a) selected(s2622,s2850,a) selected(s5309,s4774,a) selected(s3767,s3768,a) selected(s3728,s3729,d) selected(s3729,s2898,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s981,s3200,c) selected(s3244,s3246,c) selected(s982,s983,c) selected(s985,s987,c) selected(s987,s1676,c) selected(s1676,s3256,c) selected(s4008,s4012,c) selected(s1335,s1339,c) selected(s1341,s1343,c) selected(s3364,s4222,c) selected(s4222,s3413,c) selected(s3413,s3416,c) selected(s3416,s3417,c) selected(s3419,s3420,c) selected(s3032,s3033,c) selected(s3070,s4291,c) selected(s4291,s4567,c) selected(s3586,s1906,c) selected(s3585,s4567,c) selected(s4567,s4216,c) selected(s2712,s2713,c) selected(s3442,s3444,c) selected(s3450,s4218,c) selected(s4218,s3368,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s2138,s2140,b) selected(s1051,s1054,b) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s4099,s4101,b) selected(s373,s3083,b) selected(s3083,s3084,b) selected(s3095,s3097,b) selected(s1671,s2031,b) selected(s2476,s2477,b) selected(s1887,s3044,b) selected(s3053,s3056,b) selected(s3061,s3066,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2223,s2228,b) selected(s2240,s3812,b) selected(s3926,s4157,b) selected(s4157,s367,b) selected(s3927,s1788,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s2038,s2040,b) selected(s878,s5477,e) selected(s839,s882,e) selected(s882,s887,e) selected(s1600,s1602,e) selected(s1619,s1612,e) selected(s3234,s3235,e) selected(s3238,s3240,e) selected(s3242,s4232,e) selected(s3246,s3247,e) selected(s3250,s3251,e) selected(s4008,s4010,e) selected(s2384,s2386,e) selected(s4086,s4088,e) selected(s4088,s4090,e) selected(s4097,s4253,e) selected(s3185,s3189,e) selected(s3190,s3191,e) selected(s3191,s3192,e) selected(s3197,s3199,e) selected(s3209,s3210,e) selected(s906,s910,e) selected(s3061,s373,w) selected(s381,s2237,w) selected(s2237,s381,w) selected(s965,s987,w) selected(s974,s979,w) selected(s1631,s1598,w) selected(s2223,s3543,w) selected(s2228,s3536,w) selected(s2231,s3533,w) selected(s2387,s2663,w) selected(s2663,s2387,w) selected(s3056,s3084,w) selected(s3076,s3066,w) selected(s3069,s3072,w) selected(s3190,s3250,w) selected(s3250,s3190,w) selected(s3246,s3192,w) selected(s4232,s3195,w) selected(s3199,s3241,w) selected(s3241,s3199,w) selected(s3234,s3209,w) selected(s3210,s3232,w) selected(s3362,s3370,w) selected(s3413,s3450,w) selected(s3447,s3416,w) selected(s3546,s5401,w) selected(s5401,s3546,w) selected(s3992,s3917,w) selected(s4099,s4006,w) selected(s4216,s4291,w) selected(s4291,s4216,w) selected(s4218,s4222,w)
# Optimization: 129
# Answer: 14
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s2663,s3533,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3543,s3545,a) selected(s3549,s3550,a) selected(s3550,s3551,a) selected(s3553,s3555,a) selected(s3559,s3562,a) selected(s3562,s2763,a) selected(s2763,s2843,a) selected(s2843,s2845,a) selected(s2612,s2614,a) selected(s2614,s2618,a) selected(s2622,s2850,a) selected(s5309,s4774,a) selected(s3767,s3768,a) selected(s3728,s3729,d) selected(s3729,s2898,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s981,s3200,c) selected(s3244,s3246,c) selected(s982,s983,c) selected(s985,s987,c) selected(s987,s1676,c) selected(s1676,s3256,c) selected(s4008,s4012,c) selected(s1335,s1339,c) selected(s1341,s1343,c) selected(s3364,s4222,c) selected(s4222,s3413,c) selected(s3413,s3416,c) selected(s3416,s3417,c) selected(s3419,s3420,c) selected(s3032,s3033,c) selected(s3070,s4291,c) selected(s4291,s4567,c) selected(s3586,s1906,c) selected(s3585,s4567,c) selected(s4567,s4216,c) selected(s2712,s2713,c) selected(s3442,s3444,c) selected(s3450,s4218,c) selected(s4218,s3368,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s2138,s2140,b) selected(s1051,s1054,b) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s4099,s4101,b) selected(s373,s3083,b) selected(s3083,s3084,b) selected(s3095,s3097,b) selected(s1671,s2031,b) selected(s2476,s2477,b) selected(s1887,s3044,b) selected(s3053,s3056,b) selected(s3061,s3066,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2223,s2228,b) selected(s2240,s3812,b) selected(s3926,s4157,b) selected(s4157,s367,b) selected(s3927,s1788,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s2038,s2040,b) selected(s878,s5477,e) selected(s839,s882,e) selected(s882,s887,e) selected(s1600,s1602,e) selected(s1619,s1612,e) selected(s3234,s3235,e) selected(s3238,s3240,e) selected(s3242,s4232,e) selected(s3246,s3247,e) selected(s3250,s3251,e) selected(s4008,s4010,e) selected(s2384,s2386,e) selected(s4086,s4088,e) selected(s4088,s4090,e) selected(s4097,s4253,e) selected(s3185,s3189,e) selected(s3190,s3191,e) selected(s3191,s3192,e) selected(s3197,s3199,e) selected(s3209,s3210,e) selected(s906,s910,e) selected(s3061,s373,w) selected(s381,s2237,w) selected(s2237,s381,w) selected(s965,s987,w) selected(s974,s979,w) selected(s1631,s1598,w) selected(s2223,s3543,w) selected(s2228,s3536,w) selected(s2231,s3533,w) selected(s2387,s2663,w) selected(s2663,s2387,w) selected(s3076,s3066,w) selected(s3069,s3072,w) selected(s3190,s3250,w) selected(s3250,s3190,w) selected(s3246,s3192,w) selected(s4232,s3195,w) selected(s3199,s3241,w) selected(s3241,s3199,w) selected(s3234,s3209,w) selected(s3210,s3232,w) selected(s3362,s3370,w) selected(s3413,s3450,w) selected(s3447,s3416,w) selected(s3546,s5401,w) selected(s5401,s3546,w) selected(s3992,s3917,w) selected(s4099,s4006,w) selected(s4216,s4291,w) selected(s4291,s4216,w) selected(s4218,s4222,w)
# Optimization: 128
# Answer: 15
# ...
# Optimization: 35
# Answer: 107
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s2612,s2614,a) selected(s3728,s3729,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s3244,s3246,c) selected(s3419,s3420,c) selected(s4291,s4567,c) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3095,s3097,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3568,s3571,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w) selected(s3992,s3917,w)
# Optimization: 34
# Answer: 108
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s2612,s2614,a) selected(s3728,s3729,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s3244,s3246,c) selected(s3419,s3420,c) selected(s4291,s4567,c) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3095,s3097,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w) selected(s3992,s3917,w)
# Optimization: 33
# Answer: 109
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s2612,s2614,a) selected(s3728,s3729,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s3244,s3246,c) selected(s3419,s3420,c) selected(s4291,s4567,c) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3095,s3097,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w)
# Optimization: 32
# Answer: 110
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s2612,s2614,a) selected(s3728,s3729,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s3244,s3246,c) selected(s3419,s3420,c) selected(s4291,s4567,c) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s1055,s3036,b) selected(s5348,s3989,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w)
# Optimization: 31
# Answer: 111
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s2612,s2614,a) selected(s3728,s3729,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s3244,s3246,c) selected(s3419,s3420,c) selected(s4291,s4567,c) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s1055,s3036,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3560,s3566,b) selected(s3566,s3568,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w)
# Optimization: 30
# Answer: 112
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s2612,s2614,a) selected(s3728,s3729,d) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s3244,s3246,c) selected(s3419,s3420,c) selected(s4291,s4567,c) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s1055,s3036,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3560,s3566,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w)
# Optimization: 29
# Answer: 113
# selected(s3820,s3821,a) selected(s3530,s3531,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s2612,s2614,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s3244,s3246,c) selected(s3419,s3420,c) selected(s4291,s4567,c) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s1055,s3036,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3560,s3566,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w)
# Optimization: 28
# Answer: 114
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s2612,s2614,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s3244,s3246,c) selected(s3419,s3420,c) selected(s4291,s4567,c) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s1055,s3036,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3560,s3566,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w)
# Optimization: 27
# Answer: 115
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s3244,s3246,c) selected(s3419,s3420,c) selected(s4291,s4567,c) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s1055,s3036,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3560,s3566,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w)
# Optimization: 26
# Answer: 116
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s3244,s3246,c) selected(s3419,s3420,c) selected(s4291,s4567,c) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s1055,s3036,b) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w)
# Optimization: 25
# Answer: 117
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s3244,s3246,c) selected(s3419,s3420,c) selected(s4291,s4567,c) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w)
# Optimization: 24
# Answer: 118
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s3419,s3420,c) selected(s4291,s4567,c) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w)
# Optimization: 23
# Answer: 119
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s3419,s3420,c) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w)
# Optimization: 22
# Answer: 120
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3540,s3541,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w)
# Optimization: 21
# Answer: 121
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s906,s910,e) selected(s974,s979,w)
# Optimization: 20
# Answer: 122
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s2133,s2135,b) selected(s3234,s3235,e) selected(s974,s979,w)
# Optimization: 19
# Answer: 123
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s2712,s2713,c) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s3234,s3235,e) selected(s974,s979,w)
# Optimization: 18
# Answer: 124
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s1052,s2133,b) selected(s3234,s3235,e) selected(s974,s979,w)
# Optimization: 17
# Answer: 125
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s3234,s3235,e) selected(s974,s979,w)
# Optimization: 16
# Answer: 126
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s1349,s1353,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s3573,s5401,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s3234,s3235,e) selected(s974,s979,w)
# Optimization: 15
# Answer: 127
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s2240,s3812,b) selected(s1789,s1049,b) selected(s974,s979,w)
# Optimization: 14
# Answer: 128
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s1795,s1823,d) selected(s2905,s2906,d) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s2240,s3812,b) selected(s1789,s1049,b)
# Optimization: 13
# Answer: 129
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s2905,s2906,d) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s2240,s3812,b) selected(s1789,s1049,b)
# Optimization: 12
# Answer: 130
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3550,s3551,a) selected(s3559,s3562,a) selected(s2763,s2843,a) selected(s2905,s2906,d) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s1789,s1049,b)
# Optimization: 11
# Answer: 131
# selected(s3820,s3821,a) selected(s3539,s3540,a) selected(s3559,s3562,a) selected(s2905,s2906,d) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s2240,s3812,b) selected(s1789,s1049,b)
# Optimization: 10
# Answer: 132
# selected(s3820,s3821,a) selected(s3559,s3562,a) selected(s2905,s2906,d) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s2240,s3812,b) selected(s1789,s1049,b)
# Optimization: 9
# Answer: 133
# selected(s3820,s3821,a) selected(s3559,s3562,a) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s2240,s3812,b) selected(s1789,s1049,b)
# Optimization: 8
# Answer: 134
# selected(s3820,s3821,a) selected(s1349,s1353,c) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s2240,s3812,b) selected(s1789,s1049,b)
# Optimization: 7
# Answer: 135
# selected(s3820,s3821,a) selected(s4253,s3184,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s2240,s3812,b) selected(s1789,s1049,b)
# Optimization: 6
# Answer: 136
# selected(s3820,s3821,a) selected(s1349,s1353,c) selected(s3821,s381,b) selected(s381,s4099,b) selected(s2240,s3812,b)
# Optimization: 5
# Answer: 137
# selected(s3820,s3821,a) selected(s1349,s1353,c) selected(s3821,s381,b) selected(s381,s4099,b)
# Optimization: 4
# Answer: 138
# selected(s3820,s3821,a) selected(s3821,s381,b) selected(s381,s4099,b)
# Optimization: 3
# OPTIMUM FOUND
#
# Models       : 138
#   Optimum    : yes
# Optimization : 3
# Calls        : 1
# Time         : 7431.203s (Solving: 7412.28s 1st Model: 7064.95s Unsat: 1.18s)
# CPU Time     : 7347.130s
